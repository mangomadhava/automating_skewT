# %%
from calculations import *
from plotting import *

# %%
get_equivalent_potential_temperature(700 * units.hPa, 10 * units.degC, 3 * units.degC)
# Out:
# 335.0729026491377 <Unit('kelvin')>

# %%
get_LCL(1000 * units.hPa, 40 * units.degC, 18 * units.degC)
# Out:
# (730.1465681219009 <Unit('hectopascal')>,
#  13.09522390013323 <Unit('degree_Celsius')>)

# %%
get_wet_bulb_temperature(1000 * units.hPa, 40 * units.degC, 18 * units.degC)
# Out:
# 24.06016113630038 <Unit('degree_Celsius')>

# %%
plot_dict = {'constant_pressure': [(700 * units.hPa, 0 * units.degC, 20 * units.degC)], 
            'constant_temp': [(10 * units.degC, 800 * units.hPa,400 * units.hPa)]}
print(plot_dict)
metpy_plot_lines(plot_dict)
# Out:
# {'constant_pressure': [(<Quantity(700, 'hectopascal')>, <Quantity(0, 'degree_Celsius')>, <Quantity(20, 'degree_Celsius')>)], 'constant_temp': [(<Quantity(10, 'degree_Celsius')>, <Quantity(800, 'hectopascal')>, <Quantity(400, 'hectopascal')>)]}

# %%
plot_dict = {'dry_adiabats': [(10 * units.degC,800 * units.hPa,400 * units.hPa)],
            'moist_adiabats': [(20 * units.degC, 600 * units.hPa, 200 * units.hPa)],
            'mixing_ratio': [(0.000166497295, 1000 * units.hPa, 883 * units.hPa), (.01, 500 * units.hPa, 400 * units.hPa)]}
metpy_plot_lines(plot_dict)
